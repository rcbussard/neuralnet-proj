# %% [markdown]
# # 1.0 Data Download and Preparation
# ### This notebook will walk you through the following:
#
#
# *   Downloading optical data of your choosing (for this notebook we'll be downloading Landsat-8 data)
# *   Downloading the National Land Cover Database Product
# *   Creating a label file from the Land Cover Product
#
# To learn more about the various commands available for Google Earth Engine beyond the ones used in this notebook, check out their reference documentation: https://developers.google.com/earth-engine/apidocs

# %% [markdown]
# ## 1.1 Notebook Setup
#
# For this notebook, we will need to download data and implement commands from Google Earth Engine. To begin, we will import Google Earth Engine (ee), get authorized to access Earth Engine, and then initialize a session using it in the notebook.
#
# **Note: if you do not have a Google Earth Engine project already set up to enter into the 'ee.Initialize(project=)' command, go to the link below, scroll down to the Getting Access section and click on the link for the 'project registration page' in the tip box.**
#
# https://developers.google.com/earth-engine/guides/access

# %%
import ee

# %%
ee.Authenticate()

# %%
ee.Initialize(project='ee-data-download-prep') # change ee-data-download-prep to the name of your GEE project

# %% [markdown]
# ## 1.2 Searching Images to Download from GEE
#
# Now we begin by searching for the images we wish to download for our work. This is done with the ImageCollection command, and is set up to filter search images by path, row, and cloud cover percentage. These variables are setup below and can be changed based on the path, row, and cloud cover desired by the user.
#
# There are other ways to filter images using the ImageCollection command, a few resources to learn more are:
#
# *   https://tutorials.geemap.org/ImageCollection/image_collection_overview/
# *   https://developers.google.com/earth-engine/apidocs/ee-imagecollection

# %%
PATH_VAR  = 46
ROW_VAR   = 28
CLOUD_VAR = 5

# %%
L8_collection = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2').filter(ee.Filter.eq('WRS_PATH', PATH_VAR)).filter(ee.Filter.eq('WRS_ROW', ROW_VAR)).filterMetadata('CLOUD_COVER', 'less_than', CLOUD_VAR)

# %% [markdown]
# The following cell will print how many images were found for download based on the specifications in the ImageCollection command.

# %%
L8_collectionList = L8_collection.toList(L8_collection.size())
L8_collectionSize = L8_collectionList.size().getInfo()

print(L8_collectionSize)
# Out:
# 45

# %% [markdown]
# ## 1.25 Define a Region of Interest (Optional)
#
# The following two cells are for defining a region of interest (ROI) within the selected scenes for download. This is typically done both for download speed and to conserve memory, as often the entire scene is not needed. If however, we wish to download the whole scene, skip these cells and go direction to section 1.3. There will be one additional step that will be documented later on.

# %%
W_COORD = -122.62
E_COORD = -121.9
N_COORD = 46.45
S_COORD = 46.07

# %%
ROI = ee.Geometry.Rectangle([W_COORD, S_COORD, E_COORD, N_COORD])

# %% [markdown]
# ## 1.3 Download Images to Google Drive
#
# We can now begin the process of downloading images from Google Earth Engine to Google Drive. **Note you will need to create a folder in your Google Drive Account for where you want the images to be dowloaded to.** When you have done so, enter the name into the text string in the cell below.

# %%
FOLDER_NAME = 'NOTEBOOK_TEST_FOLDER'

# %% [markdown]
# Next we will define which band of the selected images we want to download. For example, for images from Landsat 8, there are seven Surface Reflectance bands to choose from (SR_B1, SR_B2, SR_B3, SR_B4, SR_B5, SR_B6, and SR_B7) and one Surface Temperature Band (ST_B10).

# %%
BAND = 'SR_B2'

# %% [markdown]
# The naming convention of the downloaded images is set up to be the name of the image, the band chosen, as well as the date the image was acquired by the satellite. Choose what each image will be named and enter it into the text string below.

# %%
NAME = 'MSH'

# %% [markdown]
# The remaining variables to be set are for the download command: ee.batch.Export.image.toDrive.
#
# *   DESC is a text string descriptor for the job being run
# *   SCALE is is the resolution in meters per pixel in the downloaded images
# *   CRS is the coordinate reference system for the images (note that it is currently set with the EPSG for WGS84)
# *   FF is the file format (currently only GeoTIFF and TFRecord are supported in GEE)
#
# Note there are additional options for this command and not all the options used here are required. **If you do not want to download a region of interest within your scenes and instead want the whole scene, delete the 'region=ROI,' portion of the command.** If you wish to learn more about the command, see here:
# https://developers.google.com/earth-engine/apidocs/export-image-todrive

# %%
DESC = 'L8_Download'
SCALE = 30
CRS = 'EPSG:4326'
FF = 'GeoTIFF'

# %%
for i in range(L8_collectionSize):
  l8_image = ee.Image(L8_collectionList.get(i)).select([BAND])
  print(l8_image.getInfo())
  image_date = str(l8_image.get('DATE_ACQUIRED').getInfo())
  full_title = NAME + '_' + BAND + '_' + image_date
  print(full_title)
  task = ee.batch.Export.image.toDrive(image=l8_image,
                                      description=DESC,
                                      scale=SCALE,
                                      region=ROI,
                                      fileNamePrefix=full_title,
                                      crs=CRS,
                                      fileFormat=FF,
                                      folder=FOLDER_NAME)
  task.start()
  print(task.status())
# Out:
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 432585, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20130703', 'version': 1629897570468917, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-123.24959768764617, 47.0891224425124], [-123.25022757717805, 47.08868949064404], [-123.27208016387733, 47.02809610589206], [-123.8450652590295, 45.38692932566067], [-123.8475117825429, 45.37939790481123], [-123.84274874038525, 45.37852019232812], [-123.15386732220479, 45.25865566139378], [-121.577021480554, 44.96660847240259], [-121.54925012569504, 44.9613065327265], [-121.54855522606302, 44.96178257153893], [-121.5409129572937, 44.98138012295022], [-121.2721741545677, 45.67335401479753], [-121.25375566130347, 45.7205992026345], [-121.14421460016591, 46.0010440708546], [-120.92076021759544, 46.56420601567681], [-120.89778524235214, 46.62183479872589], [-120.8801412779265, 46.66642999418136], [-120.90909232503384, 46.671982434171376], [-122.97943416224336, 47.04373203874645], [-123.24959768764617, 47.0891224425124]]}, 'REFLECTIVE_SAMPLES': 7781, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 140.07080507, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2013-07-03', 'ELLIPSOID': 'WGS84', 'system:time_end': 1372877881903, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20130703_20200912_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1372877881903, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-09-12T20:28:14Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 0.41, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0166989, 'GEOMETRIC_RMSE_VERIFY': 1.854, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:58:01.9030250Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 62.24881736, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 0.41, 'GEOMETRIC_RMSE_MODEL': 3.376, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599943204000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'N', 'LANDSAT_SCENE_ID': 'LC80460282013184LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20130703_20200912_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1326, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418, 'GEOMETRIC_RMSE_MODEL_Y': 2.476 ...
# MSH_SR_B2_2013-07-03
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413017655, 'update_timestamp_ms': 1704413017655, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'QKSO36EHC62V2AIKXFYOJF3P', 'name': 'projects/ee-data-download-prep/operations/QKSO36EHC62V2AIKXFYOJF3P'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7791, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 431985, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20130804', 'version': 1629897570953705, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-122.02751491951103, 45.051810878775264], [-121.55321438590124, 44.96124397811261], [-121.55235787315908, 44.96183079492018], [-121.54541502338343, 44.9796383616776], [-121.27560596915146, 45.67448597906524], [-121.25802776347558, 45.71958432748502], [-121.14724038297881, 46.00325331669749], [-120.92509397159164, 46.56347474142286], [-120.90255710864807, 46.62003265048619], [-120.88445554985881, 46.66601817724535], [-120.88570991295592, 46.66647935748448], [-120.92156978627615, 46.67335367018562], [-123.08569662981289, 47.060709305890946], [-123.24037982845451, 47.08662658222259], [-123.25377503976864, 47.088813958722696], [-123.25532267226907, 47.08881049670439], [-123.85255003132018, 45.37950344054194], [-123.83695624083438, 45.376800113924816], [-123.06437601487325, 45.24199830791394], [-122.02751491951103, 45.051810878775264]]}, 'REFLECTIVE_SAMPLES': 7791, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 144.58617014, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2013-08-04', 'ELLIPSOID': 'WGS84', 'system:time_end': 1375642683637, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20130804_20200912_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1375642683637, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-09-12T15:51:12Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 4.43, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0144917, 'GEOMETRIC_RMSE_VERIFY': 1.74, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:58:03.6374570Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 56.83857289, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 4.43, 'GEOMETRIC_RMSE_MODEL': 2.748, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599926620000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282013216LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20130804_20200912_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1247, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418, 'GEOMETRIC_RMSE_M ...
# MSH_SR_B2_2013-08-04
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413020021, 'update_timestamp_ms': 1704413020021, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'HHMLBA7FP6HYNQ3IQOOYVFRL', 'name': 'projects/ee-data-download-prep/operations/HHMLBA7FP6HYNQ3IQOOYVFRL'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7791, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 431385, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20130820', 'version': 1629897571195132, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-120.89290807920315, 46.66536086475463], [-120.89351600114668, 46.66580245844576], [-120.93128735951001, 46.67304011949511], [-123.00668434602147, 47.04535347398825], [-123.24778492932437, 47.08584965407298], [-123.26453894083258, 47.08860100500266], [-123.26524535480634, 47.08811521819839], [-123.86072282268033, 45.383300819157164], [-123.86188422817897, 45.379572407620195], [-123.86047201210312, 45.37908805028568], [-123.77012455666365, 45.36364010276365], [-121.57322481243119, 44.96323940167659], [-121.56093406148229, 44.960893293631955], [-121.55461209820042, 44.977054373623574], [-121.539945467608, 45.01521670407314], [-121.28160078240967, 45.679976889114904], [-121.26988718669405, 45.71004359445013], [-121.15114048758387, 46.014117078140444], [-120.93374079962298, 46.56255136058476], [-120.9120795418337, 46.616966754302716], [-120.89290807920315, 46.66536086475463]]}, 'REFLECTIVE_SAMPLES': 7791, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 148.95208233, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2013-08-20', 'ELLIPSOID': 'WGS84', 'system:time_end': 1377025084882, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20130820_20200913_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1377025084882, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-09-13T02:15:05Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 1.56, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0116724, 'GEOMETRIC_RMSE_VERIFY': 1.566, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:58:04.8826560Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 52.65055755, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 1.56, 'GEOMETRIC_RMSE_MODEL': 2.618, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599963896000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282013232LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 
'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 3.57, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 0.9871843, 'GEOMETRIC_RMSE_VERIFY': 9.901, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:57:38.9424220Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 21.96578882, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 3.58, 'GEOMETRIC_RMSE_MODEL': 8.466, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599900673000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'N', 'LANDSAT_SCENE_ID': 'LC80460282013328LGN02', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20131124_20200912_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 998, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BAND_S ...
# MSH_SR_B2_2013-11-24
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413024424, 'update_timestamp_ms': 1704413024424, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'XEC6ZN6VQ4YQVT67HIEBEVGK', 'name': 'projects/ee-data-download-prep/operations/XEC6ZN6VQ4YQVT67HIEBEVGK'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7791, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 433185, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20140706', 'version': 1629897575663417, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-123.83694124487863, 45.38101688367867], [-123.83692718308727, 45.38006267122635], [-123.83635304305989, 45.37966640216476], [-123.83048769257312, 45.37860983885338], [-123.28399544441172, 45.28379043761161], [-122.02253072716108, 45.0536587328676], [-121.53705973101032, 44.96087443577099], [-121.52360999964431, 44.9956501122612], [-121.26066597079317, 45.67182913578334], [-121.23846521534387, 45.72873523602024], [-121.13561635154667, 45.99172353629261], [-120.90865471255117, 46.563445059035914], [-120.88567790480472, 46.62080114058911], [-120.86951518793423, 46.66125953612691], [-120.86814147443951, 46.665402110191266], [-120.8688305025696, 46.665902820830205], [-123.20831366462325, 47.083990437991005], [-123.23756881248396, 47.08884870946001], [-123.23950793767581, 47.088844673390355], [-123.83142479025234, 45.39756174572117], [-123.83694124487863, 45.38101688367867]]}, 'REFLECTIVE_SAMPLES': 7791, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 139.21750116, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2014-07-06', 'ELLIPSOID': 'WGS84', 'system:time_end': 1404672952703, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20140706_20200911_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1404672952703, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-09-11T10:20:26Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 4.14, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0166626, 'GEOMETRIC_RMSE_VERIFY': 2.047, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:55:52.7036160Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 61.72498659, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 4.15, 'GEOMETRIC_RMSE_MODEL': 3.542, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599820300000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'Y', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282014187LGN02', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 
ROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-09-11T01:26:09Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 3.08, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0140443, 'GEOMETRIC_RMSE_VERIFY': 1.612, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:56:04.6702610Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 55.97992504, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 3.08, 'GEOMETRIC_RMSE_MODEL': 2.73, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599788194000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282014219LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20140807_20200911_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1325, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418, 'GEOMETRIC_RMSE_MODE ...
# MSH_SR_B2_2014-08-07
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413028800, 'update_timestamp_ms': 1704413028800, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'OBF3MCUHSE3M7GCAKDZW5A5A', 'name': 'projects/ee-data-download-prep/operations/OBF3MCUHSE3M7GCAKDZW5A5A'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0,
, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1602784573000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'Y', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282015110LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20150420_20201015_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1259, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMU ...
# MSH_SR_B2_2015-04-20
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413030939, 'update_timestamp_ms': 1704413030939, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'S2GPZEXERFIHBDRKHAKHZYQV', 'name': 'projects/ee-data-download-prep/operations/S2GPZEXERFIHBDRKHAKHZYQV'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 433185, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20150607', 'version': 1629897580067560.0, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-123.83788430775998, 45.37965430697466], [-123.82587289859015, 45.377562846119226], [-122.16159879085102, 45.07933939312974], [-121.56573192703954, 44.96587819760709], [-121.54021706014491, 44.96100454246097], [-121.53854651711394, 44.96098314960768], [-121.52359414538559, 44.99961289273822], [-121.26222261998946, 45.67131281786496], [-121.23960436305116, 45.7292927775411], [-121.13634543578546, 45.99308540516264], [-120.90982819618974, 46.5634665349211], [-120.88641899346447, 46.62189483407954], [-120.87207897958207, 46.657808830350014], [-120.8691272045307, 46.66542439770424], [-122.31228403865893, 46.92990350574305], [-123.22728872715503, 47.086915380326595], [-123.23995886706163, 47.08897686329868], [-123.24074020809368, 47.0884399427768], [-123.8332999324621, 45.396543508786245], [-123.83872939070808, 45.380237645552896], [-123.83788430775998, 45.37965430697466]]}, 'REFLECTIVE_SAMPLES': 7781, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 141.38059289, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2015-06-07', 'ELLIPSOID': 'WGS84', 'system:time_end': 1433703315831, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20150607_20201015_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1433703315831, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-10-15T17:12:59Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 0.16, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0148786, 'GEOMETRIC_RMSE_VERIFY': 2.025, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:55:15.8312480Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 62.43919208, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 0.16, 'GEOMETRIC_RMSE_MODEL': 3.786, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1602785388000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'N', 'LANDSAT_SCENE_ID': 'LC80460282015158LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20150607_20201015_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1306, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BA ...
# MSH_SR_B2_2015-06-07
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413033332, 'update_timestamp_ms': 1704413033332, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 
'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 2.44, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.010537, 'GEOMETRIC_RMSE_VERIFY': 1.261, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:55:50.4219200Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 50.8415625, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 2.44, 'GEOMETRIC_RMSE_MODEL': 1.813, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599591505000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'N', 'LANDSAT_SCENE_ID': 'LC80460282015238LGN02', 'SATURATION_BAND_5': 'N', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20150826_20200908_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1393, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418, 'GEOMETRIC_RMSE_MOD ...
# MSH_SR_B2_2015-08-26
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413035810, 'update_timestamp_ms': 1704413035810, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '4YJZAMCAZUTNS7FQUNTK63RK', 'name': 'projects/ee-data-download-prep/operations/4YJZAMCAZUTNS7FQUNTK63RK'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 432885, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20150927', 'version': 1629897581518284, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-123.21180845937903, 47.083492106915934], [-123.2465151859834, 47.08927518678639], [-123.24708561804205, 47.08809403997475], [-123.84053890356527, 45.39182396432398], [-123.84446090857656, 45.379954571287556], [-123.81817856391062, 45.3754577546955], [-123.05137910535738, 45.24146478134215], [-121.5452896504663, 44.96133937228073], [-121.54402808901607, 44.96132325361745], [-121.53342798135108, 44.98853929616694], [-121.26633241848572, 45.67542570922725], [-121.24707013405677, 45.7248172331581], [-121.14045975892913, 45.997472767450994], [-120.91525279908404, 46.56491555259453], [-120.89271568676594, 46.62120134822446], [-120.87517705313243, 46.665519935775315], [-120.87585953641057, 46.666015836752514], [-120.91489603572539, 46.673502184050434], [-122.67604543023693, 46.99252275945835], [-123.00589473572668, 47.04886298531114], [-123.21180845937903, 47.083492106915934]]}, 'REFLECTIVE_SAMPLES': 7781, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 158.74468952, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2015-09-27', 'ELLIPSOID': 'WGS84', 'system:time_end': 1443380163350, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20150927_20200908_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1443380163350, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'L1_DATE_PRODUCT_GENERATED': '2020-09-08T09:40:51Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'NOMINAL', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 0.26, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0022591, 'GEOMETRIC_RMSE_VERIFY': 3.057, 'TIRS_SSM_MODEL': 'ACTUAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:56:03.3505660Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 40.16967587, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 0.26, 'GEOMETRIC_RMSE_MODEL': 3.933, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599558641000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'N', 'LANDSAT_SCENE_ID': 'LC80460282015270LGN01', 'SATURATION_BAND_5': 'N', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 
RS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 0.14, 'REQUEST_ID': 'L2', 'EARTH_SUN_DISTANCE': 1.0131713, 'GEOMETRIC_RMSE_VERIFY': 1.423, 'TIRS_SSM_MODEL': 'FINAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:56:05.4979440Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 54.60178349, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.3.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 0.14, 'GEOMETRIC_RMSE_MODEL': 2.874, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1599396122000, 'L1_REQUEST_ID': 'L2', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'N', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282016225LGN01', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_15.3.1c', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20160812_20200906_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.5.0', 'GROUND_CONTROL_POINTS_MODEL': 1344, 'SPACECRAFT_ID ...
# MSH_SR_B2_2016-08-12
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413040259, 'update_timestamp_ms': 1704413040259, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '45KIIITLVS3CRXFND5XCXEQM', 'name': 'projects/ee-data-download-prep/operations/45KIIITLVS3CRXFND5XCXEQM'}
# ...
# MSH_SR_B2_2023-06-29
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413102855, 'update_timestamp_ms': 1704413102855, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '4B3X4VCZRRMRZ4T25U23A7KT', 'name': 'projects/ee-data-download-prep/operations/4B3X4VCZRRMRZ4T25U23A7KT'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 432885, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20230715', 'version': 1690358182487902, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[
ND_1': 'Y', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282023196LGN00', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.0', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20230715_20230724_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0', 'GROUND_CONTROL_POINTS_MODEL': 1285, 'SPACECRAFT_ID': 'LANDSAT_8', 'TEMPERATURE_MINIMUM_BAND_ST_B10': 149.003418, 'GEOMETRIC_RMSE_MODEL_Y': 2.948, 'REFLECTI ...
# MSH_SR_B2_2023-07-15
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413105088, 'update_timestamp_ms': 1704413105088, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'EML4WQ7ZQS5N73JHTTTAOUPB', 'name': 'projects/ee-data-download-prep/operations/EML4WQ7ZQS5N73JHTTTAOUPB'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 432585, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20230731', 'version': 1691392928363269, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-120.8729051052543, 46.656743973204726], [-120.87019566432322, 46.66368457996528], [-120.87171332784223, 46.66406451882707], [-120.90131329212998, 46.669743862912306], [-122.14804220534738, 46.89910250149342], [-123.22211509862247, 47.08435944837423], [-123.24066308014895, 47.08740973077283], [-123.24152343867148, 47.08681849544774], [-123.83329475135206, 45.397404537860496], [-123.83922009884462, 45.379650000142455], [-123.83919656334514, 45.37805790944079], [-123.82238918564212, 45.375157565557615], [-123.71487556888263, 45.35670811287833], [-121.53979972206328, 44.9589398778781], [-121.52355943928347, 45.00096280845221], [-121.26259927516325, 45.67158851722632], [-121.23998133142588, 45.7295685983503], [-121.13672357036049, 45.99336161950432], [-120.91021941687417, 46.5634736998656], [-120.88681063864121, 46.62190204281087], [-120.8729051052543, 46.656743973204726]]}, 'REFLECTIVE_SAMPLES': 7781, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 142.66230324, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2023-07-31', 'ELLIPSOID': 'WGS84', 'system:time_end': 1690829753356, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20230731_20230805_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1690829753356, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.0', 'L1_DATE_PRODUCT_GENERATED': '2023-08-05T14:00:29Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 1.46, 'REQUEST_ID': '1769474_00034', 'EARTH_SUN_DISTANCE': 1.0150805, 'GEOMETRIC_RMSE_VERIFY': 1.861, 'TIRS_SSM_MODEL': 'FINAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:55:53.3569640Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 57.61045932, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 1.46, 'GEOMETRIC_RMSE_MODEL': 3.938, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1691245837000, 'L1_REQUEST_ID': '1769474_00034', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'Y', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'Y', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'Y', 'LANDSAT_SCENE_ID': 'LC80460282023212LGN00', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.0', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20230731_20230805_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0', 'GROUND_CONTROL_POINTS_MODEL': 1256, 'SPACECRAFT_ID': 'LANDSAT_8', 'TE ...
# MSH_SR_B2_2023-07-31
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413107404, 'update_timestamp_ms': 1704413107404, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': '6777GLPRAC6T6BLJ5OJ3LHQO', 'name': 'projects/ee-data-download-prep/operations/6777GLPRAC6T6BLJ5OJ3LHQO'}
# {'type': 'Image', 'bands': [{'id': 'SR_B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7781, 7901], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 432585, 0, -30, 5215515]}], 'id': 'LANDSAT/LC08/C02/T1_L2/LC08_046028_20230816', 'version': 1692476419394006, 'properties': {'DATA_SOURCE_ELEVATION': 'GLS2000', 'WRS_TYPE': 2, 'REFLECTANCE_ADD_BAND_1': -0.2, 'REFLECTANCE_ADD_BAND_2': -0.2, 'DATUM': 'WGS84', 'REFLECTANCE_ADD_BAND_3': -0.2, 'REFLECTANCE_ADD_BAND_4': -0.2, 'REFLECTANCE_ADD_BAND_5': -0.2, 'REFLECTANCE_ADD_BAND_6': -0.2, 'REFLECTANCE_ADD_BAND_7': -0.2, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-123.23974943997307, 47.0869544722042], [-123.24033643593602, 47.08655105181182], [-123.8317975017872, 45.39787243673362], [-123.838062523179, 45.37910152053594], [-123.83804622050144, 45.37800580507471], [-123.82469600354767, 45.37568106699667], [-123.47054141651239, 45.31449932852123], [-121.67852989089023, 44.98592247592456], [-121.53954686187143, 44.959105559671514], [-121.53808054233716, 44.95908678782524], [-121.53755855160664, 44.95979576170188], [-121.52426047474802, 44.99422971488921], [-121.2602558330888, 45.67263297085239], [-121.23805440134645, 45.729538935848424], [-121.1352111082805, 45.99225690935805], [-120.90868584363152, 46.562635676651816], [-120.88527579545568, 46.62106386180328], [-120.868480981412, 46.6632908954697], [-120.86973738353733, 46.66375302716911], [-120.88067835645198, 46.6658535097372], [-123.23795980935938, 47.08695816514462], [-123.23974943997307, 47.0869544722042]]}, 'REFLECTIVE_SAMPLES': 7781, 'GROUND_CONTROL_POINTS_VERSION': 5, 'SUN_AZIMUTH': 146.88788628, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'UTM_ZONE': 10, 'DATE_ACQUIRED': '2023-08-16', 'ELLIPSOID': 'WGS84', 'system:time_end': 1692212159221, 'DATA_SOURCE_PRESSURE': 'Calculated', 'LANDSAT_PRODUCT_ID': 'LC08_L2SP_046028_20230816_20230819_02_T1', 'STATION_ID': 'LGN', 'TEMPERATURE_ADD_BAND_ST_B10': 149, 'DATA_SOURCE_REANALYSIS': 'GEOS-5 FP-IT', 'REFLECTANCE_MULT_BAND_7': 2.75e-05, 'system:time_start': 1692212159221, 'REFLECTANCE_MULT_BAND_6': 2.75e-05, 'L1_PROCESSING_LEVEL': 'L1TP', 'PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.0', 'L1_DATE_PRODUCT_GENERATED': '2023-08-19T08:18:22Z', 'ORIENTATION': 'NORTH_UP', 'REFLECTANCE_MULT_BAND_1': 2.75e-05, 'WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_3': 2.75e-05, 'REFLECTANCE_MULT_BAND_2': 2.75e-05, 'TARGET_WRS_ROW': 28, 'REFLECTANCE_MULT_BAND_5': 2.75e-05, 'REFLECTANCE_MULT_BAND_4': 2.75e-05, 'THERMAL_LINES': 7901, 'TIRS_SSM_POSITION_STATUS': 'ESTIMATED', 'GRID_CELL_SIZE_THERMAL': 30, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'NADIR_OFFNADIR': 'NADIR', 'CLOUD_COVER': 0.02, 'REQUEST_ID': '1775999_00033', 'EARTH_SUN_DISTANCE': 1.0126744, 'GEOMETRIC_RMSE_VERIFY': 1.761, 'TIRS_SSM_MODEL': 'FINAL', 'COLLECTION_CATEGORY': 'T1', 'SCENE_CENTER_TIME': '18:55:59.2219820Z', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'SUN_ELEVATION': 53.69627299, 'ALGORITHM_SOURCE_SURFACE_TEMPERATURE': 'st_1.5.0', 'TEMPERATURE_MAXIMUM_BAND_ST_B10': 372.999941, 'CLOUD_COVER_LAND': 0.02, 'GEOMETRIC_RMSE_MODEL': 3.933, 'ROLL_ANGLE': -0.001, 'COLLECTION_NUMBER': 2, 'DATE_PRODUCT_GENERATED': 1692434327000, 'L1_REQUEST_ID': '1775999_00033', 'DATA_SOURCE_OZONE': 'MODIS', 'SATURATION_BAND_1': 'N', 'DATA_SOURCE_WATER_VAPOR': 'MODIS', 'SATURATION_BAND_2': 'Y', 'SATURATION_BAND_3': 'N', 'IMAGE_QUALITY_OLI': 9, 'SATURATION_BAND_4': 'N', 'LANDSAT_SCENE_ID': 'LC80460282023228LGN00', 'SATURATION_BAND_5': 'Y', 'MAP_PROJECTION': 'UTM', 'SATURATION_BAND_6': 'Y', 'SENSOR_ID': 'OLI_TIRS', 'SATURATION_BAND_7': 'Y', 'SATURATION_BAND_8': 'N', 'WRS_PATH': 46, 'SATURATION_BAND_9': 'N', 'TARGET_WRS_PATH': 46, 'L1_PROCESSING_SOFTWARE_VERSION': 'LPGS_16.3.0', 'TEMPERATURE_MULT_BAND_ST_B10': 0.00341802, 'L1_LANDSAT_PRODUCT_ID': 'LC08_L1TP_046028_20230816_20230819_02_T1', 'PROCESSING_LEVEL': 'L2SP', 'ALGORITHM_SOURCE_SURFACE_REFLECTANCE': 'LaSRC_1.6.0', 'GROUND_CONTROL_POINTS_MODEL': 1302,  ...
# MSH_SR_B2_2023-08-16
# {'state': 'READY', 'description': 'L8_Download', 'creation_timestamp_ms': 1704413109518, 'update_timestamp_ms': 1704413109518, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'H6RJTF4QZTGNN5RBRE2AH2P6', 'name': 'projects/ee-data-download-prep/operations/H6RJTF4QZTGNN5RBRE2AH2P6'}

# %% [markdown]
# **Note: The neural network notebook that follows this notebook uses six bands worth of Landsat 8 data. If you wish to also use six bands of data for each acquisition date, once one band of data has finished downloading, change the BAND variable to a new band name and rerun, repeating the process for each band.**

# %% [markdown]
# ## 1.4 Search for Land Cover File from GEE
#
# We will re-use the ImageCollection command to search for the National Land Cover Database file. We will choose the year 2016 and then select out the 'landcover' band from the NLCD file.
#
# *   To learn more about the NLCD, check here: https://www.usgs.gov/centers/eros/science/national-land-cover-database
# *   To download the NLCD directly and see what other years are available for download, check here: https://www.mrlc.gov/data

# %%
LC_dataset = ee.ImageCollection("USGS/NLCD_RELEASES/2016_REL")
NLCD_2016 = LC_dataset.filter(ee.Filter.eq('system:index', '2016')).first()
landcover = NLCD_2016.select('landcover')

# %% [markdown]
# ## 1.5 Download Land Cover File
#
# We will re-use the ee.batch.Export.image.toDrive command to download the Land Cover file to Google Drive. Nearly all of the variables will be kept the same so that the land cover image and optical images are the same resolution and projection. Only the file name and batch job description will be changed.

# %%
nlcd_task = ee.batch.Export.image.toDrive(image=landcover,
                                      description='LandCover_Download',
                                      scale=SCALE,
                                      region=ROI,
                                      fileNamePrefix='LandCover_2016',
                                      crs=CRS,
                                      fileFormat=FF,
                                      folder=FOLDER_NAME)
nlcd_task.start()
print(nlcd_task.status())
# Out:
# {'state': 'READY', 'description': 'LandCover_Download', 'creation_timestamp_ms': 1704464157153, 'update_timestamp_ms': 1704464157153, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'RN6HCWRREZT4VVIW3H2D6EXG', 'name': 'projects/ee-data-download-prep/operations/RN6HCWRREZT4VVIW3H2D6EXG'}

# %% [markdown]
# ## 1.6 Create Label File from Land Cover File
#
# To create the label file that we will use for the next notebook that crafts the neural network, we will read in the land cover file.
#
# **Note: Make sure that the land cover file has been downloaded from Google Earth Engine to the specified folder.**
#
# You will also need to mount your Google Drive to this notebook. To do so:
#
# *   Click on the folder icon on the far left vertical toolbar (it sits beneath the key icon on the toolbar)
# *   Click on the icon third from left that shows a folder with the Google Drive symbol (if you hover over this icon with your mouse it should say 'Mount Drive')
#
# We will start by installing/importing pyrsgis for raster manipulation as well as importing gdal and numpy.

# %%
# !pip install pyrsgis
# Out:
# Collecting pyrsgis
#   Downloading pyrsgis-0.4.1-py3-none-any.whl (25 kB)
# Installing collected packages: pyrsgis
# Successfully installed pyrsgis-0.4.1

# %%
from osgeo import gdal
import numpy as np
from pyrsgis import raster

# %% [markdown]
# Then we will read in the downloaded land cover file into this notebook. To do so, change the example path below to one that includes your chosen folder name and the name you gave your land cover file.

# %%
LC_file = gdal.Open('/content/drive/MyDrive/NOTEBOOK_TEST_FOLDER/LandCover_2016.tif')

# %% [markdown]
# We will then convert the imported raster image to a 2D array so that we can interact with the data for label file creation purposes (i.e. storing the length and the width of the array).

# %%
LC_raster = LC_file.GetRasterBand(1)
LC_array = LC_raster.ReadAsArray()

# %%
print(LC_array.shape)
LC_length = LC_array.shape[0]
LC_width = LC_array.shape[1]
# Out:
# (1413, 2672)

# %% [markdown]
# We then create an empty array with the same dimensions as the land cover array.

# %%
label_array = np.empty(shape=(LC_length, LC_width), dtype='object')

# %% [markdown]
# Iterating through the land cover array, for each pixel with a value of 12 (associated with the ID snow in the land cover file) we set the value of the pixel in the label file to 1, and for all other land cover values we set the pixel in the label file to 0.
#
# **Note: this example uses the value for snow for the label file, but the user can set other values as 1 for the label file if they wish. The list of values in the label file can be found here:**
#
# https://www.mrlc.gov/data/legends/national-land-cover-database-class-legend-and-description

# %%
for i in range(LC_length):
  for j in range(LC_width):
    if LC_array[i,j] == 12:
      label_array[i,j] = 1
    else:
      label_array[i,j] = 0

# %% [markdown]
# Last, we will write the label file as a raster to the same folder as our downloaded images and our land cover tif file.

# %%
outFile = '/content/drive/MyDrive/NOTEBOOK_TEST_FOLDER/Snow_Label_File.tif'
raster.export(label_array, LC_file, filename=outFile, dtype='float')

# %% [markdown]
# At the end of this notebook, you should have a folder populated with:
# 1.   However many bands of optical data for your chosen time period
# 2.   A land cover file
# 3.   A label file that will be used in neural network construction
#
# If you have all of these files, you're ready to move to the next notebook!
